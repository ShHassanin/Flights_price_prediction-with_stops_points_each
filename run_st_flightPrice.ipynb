# %%
# !streamlit run streamlitPrediction_flightPrice.py
# Out:
# ^C

# %%
! pip install xgboost
# Out:
# ...
#    ---------------------------------------- 0.0/99.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/99.8 MB 1.3 MB/s eta 0:01:18
#    ---------------------------------------- 0.1/99.8 MB 812.7 kB/s eta 0:02:03
#    ---------------------------------------- 0.1/99.8 MB 901.1 kB/s eta 0:01:51
#    ---------------------------------------- 0.2/99.8 MB 1.5 MB/s eta 0:01:07
#    ---------------------------------------- 0.3/99.8 MB 1.4 MB/s eta 0:01:09
#    ---------------------------------------- 0.5/99.8 MB 1.8 MB/s eta 0:00:55
#    ---------------------------------------- 0.6/99.8 MB 2.0 MB/s eta 0:00:49
#    ---------------------------------------- 0.8/99.8 MB 2.2 MB/s eta 0:00:45
#    ---------------------------------------- 1.0/99.8 MB 2.4 MB/s eta 0:00:42
#    ---------------------------------------- 1.1/99.8 MB 2.5 MB/s eta 0:00:39
#     --------------------------------------- 1.3/99.8 MB 2.6 MB/s eta 0:00:38
# ...
